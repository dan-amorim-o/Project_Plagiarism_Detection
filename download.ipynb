# %%
# !pwd
# Out:
# /home/ec2-user/SageMaker/ML_SageMaker_Studies/Project_Plagiarism_Detection

# %%
# !zip -r -X Project_Plagiarism_Detection.zip /home/ec2-user/SageMaker/ML_SageMaker_Studies/Project_Plagiarism_Detection
# Out:
# updating: home/ec2-user/SageMaker/ML_SageMaker_Studies/Project_Plagiarism_Detection/ (stored 0%)
# updating: home/ec2-user/SageMaker/ML_SageMaker_Studies/Project_Plagiarism_Detection/source_pytorch/ (stored 0%)
# updating: home/ec2-user/SageMaker/ML_SageMaker_Studies/Project_Plagiarism_Detection/source_pytorch/predict.py (deflated 61%)
# updating: home/ec2-user/SageMaker/ML_SageMaker_Studies/Project_Plagiarism_Detection/source_pytorch/train.py (deflated 65%)
# updating: home/ec2-user/SageMaker/ML_SageMaker_Studies/Project_Plagiarism_Detection/source_pytorch/model.py (deflated 57%)
# updating: home/ec2-user/SageMaker/ML_SageMaker_Studies/Project_Plagiarism_Detection/1_Data_Exploration.ipynb (deflated 78%)
# updating: home/ec2-user/SageMaker/ML_SageMaker_Studies/Project_Plagiarism_Detection/helpers.py (deflated 64%)
# updating: home/ec2-user/SageMaker/ML_SageMaker_Studies/Project_Plagiarism_Detection/notebook_ims/ (stored 0%)
# ...
